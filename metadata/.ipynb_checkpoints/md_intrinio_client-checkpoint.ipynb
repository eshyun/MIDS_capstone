# %%
from api_key import INTRINIO_USERNAME
from api_key import INTRINIO_PASSWORD                 
import pandas as pd
import sys
import urllib2
import json
import requests

# %%
#print (INTRINIO_USERNAME)
#print(INTRINIO_PASSWORD)

# %%
def intrinio_get_company_metadata(symbol):
        # Get the latest FY Income Statement for "symbol"

        cleanedupdata = {}
        base_url = "https://api.intrinio.com"

        request_url = base_url + "/companies"
        query_params = {
                'ticker': symbol
        }

        response = requests.get(request_url, params=query_params, auth=(INTRINIO_USERNAME, INTRINIO_PASSWORD))
        if response.status_code == 401: print("Unauthorized! Check your username and password."); exit()

        data = response.json()
        return(json.dumps(data, indent=1, sort_keys=True))

#data = intrinio_get_company_metadata('GE')
#print(data)

# %%
def intrinio_get_company_financials(symbol, year, quarter):
        # Get the latest FY Income Statement for "symbol"

        cleanedupdata = {}
        base_url = "https://api.intrinio.com"
        request_url = base_url + "/financials/standardized"
        query_params = {
                'ticker': symbol,
                'statement': 'income_statement',
                'fiscal_year' : str(year),
                'fiscal_period' : str(quarter),
                'type': 'FY'
        }

        response = requests.get(request_url, params=query_params, auth=(INTRINIO_USERNAME, INTRINIO_PASSWORD))
        if response.status_code == 401: print("Unauthorized! Check your username and password."); exit()

        data = response.json()['data']

        for row in data:
                tag = row['tag']
                value = row['value']
                cleanedupdata["AASYMBOL"] = symbol
                cleanedupdata["ABYEAR"] = year
                cleanedupdata["ACPeriod"] = quarter
                cleanedupdata[tag] = value
                #print(tag + ": " + str(value))
        return (json.dumps(cleanedupdata, indent=1, sort_keys=True))

#data = intrinio_get_company_financials('GE', '2010', 'FY')

# %%
intrinio_get_company_financials("GE", "2014", "Q3")
# Out:
# '{\n "AASYMBOL": "GE", \n "ABYEAR": "2014", \n "ACPeriod": "Q3", \n "basicdilutedeps": 1.51, \n "basiceps": 1.51, \n "cashdividendspershare": 0.89, \n "dilutedeps": 1.5, \n "incometaxexpense": 773000000.0, \n "netincome": 15345000000.0, \n "netincomecontinuing": 9490000000.0, \n "netincomediscontinued": 5855000000.0, \n "netincometocommon": 15233000000.0, \n "netincometononcontrollinginterest": 112000000.0, \n "operatingcostofrevenue": 83704000000.0, \n "operatingrevenue": 116406000000.0, \n "othercostofrevenue": 2530000000.0, \n "otherincome": 778000000.0, \n "sgaexpense": 17963000000.0, \n "totalcostofrevenue": 86234000000.0, \n "totalgrossprofit": 30172000000.0, \n "totalinterestexpense": 2723000000.0, \n "totaloperatingexpenses": 17963000000.0, \n "totaloperatingincome": 12209000000.0, \n "totalotherincome": -1945000000.0, \n "totalpretaxincome": 10263000000.0, \n "totalrevenue": 116406000000.0, \n "weightedavebasicdilutedsharesos": 10045000000.0, \n "weightedavebasicsharesos": 10045000000.0, \n "weightedavedilutedsharesos": 10045000000.0\n}'

# %%
import csv

def intrinio_get_company_financials_csv(symbol, year, quarter):
        # Get the latest FY Income Statement for "symbol"

        cleanedupdata = {}
        base_url = "https://api.intrinio.com"
        request_url = base_url + "/financials/standardized.csv?"
        query_params = {
                'ticker': symbol,
                'statement': 'income_statement',
                'fiscal_year' : str(year),
                'fiscal_period' : str(quarter),
                'type': 'FY'
        }

        response = requests.get(request_url, params=query_params, auth=(INTRINIO_USERNAME, INTRINIO_PASSWORD))
        if response.status_code == 401: print("Unauthorized! Check your username and password."); exit()

        return(response)

# %%
intrinio_get_company_financials_csv("GE", "2006", "Q3")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-27-39445df0f1ab> in <module>()
# ----> 1 intrinio_get_company_financials_csv("GE", "2006", "Q3")
#
# <ipython-input-26-f6f27cfac40e> in intrinio_get_company_financials_csv(symbol, year, quarter)
#      19
#      20         result = csv.reader(response)
# ---> 21         return(list(result))
#
# Error: new-line character seen in unquoted field - do you need to open the file in universal-newline mode?

# %%
import sys
import json
import finsymbols

sys.path.append('/home/skillachie/Desktop/')
from finsymbols import symbols

sp500 = symbols.get_sp500_symbols()
companies = json.dumps(sp500, indent=1, sort_keys=True)

# %%
# import os
# count = 0
# def get_SandP_metadata():
#     if not os.path.exists("data"):
#         os.makedirs("data")
#     for entry in sp500:
#         datafileName = "./data/data_" + str(entry["symbol"])
#         with open(datafileName, "w") as outfile:
#             data = intrinio_get_company_metadata(entry["symbol"])
#             json.dump(data, outfile, indent=1, sort_keys=True)
#             count += 1

# %%
# # Reading data back
# with open('data/data_MMM', 'r') as f:
#      data = json.load(f)

# print(data)
# Out:
# {
#  "business_address": "3M CENTER, BLDG. 220-11W-02, ST PAUL, MN 55144-1000",
#  "business_phone_no": "6517332204",
#  "ceo": "Inge G. Thulin",
#  "cik": "0000066740",
#  "company_url": "www.3m.com",
#  "employees": 91584,
#  "entity_legal_form": "CORPORATION",
#  "entity_status": null,
#  "hq_address1": null,
#  "hq_address2": null,
#  "hq_address_city": null,
#  "hq_address_postal_code": null,
#  "hq_country": "United States of America",
#  "hq_state": "Minnesota",
#  "inc_country": "United States of America",
#  "inc_state": "Delaware",
#  "industry_category": "Manufacturing",
#  "industry_group": "Diversified Machinery",
#  "latest_filing_date": "2017-08-01",
#  "legal_name": "3M CO",
#  "lei": "LUZQVYP4VS22CLWDAR65",
#  "long_description": "3M Company operates as a diversified technology company worldwide. The company's Industrial segment offers tapes; coated, non-woven, and bonded abrasives; adhesives; advanced ceramics; sealants; specialty materials; separation and purification products; closure systems for personal hygiene products; acoustic systems products; automotive components; and abrasion-resistant films, and paint finishing and detailing products. Its Safety and Graphics Business segment provides personal protection products, traffic safety and security products, commercial graphics systems, commercial cleaning and protection products, floor matting, roofing granules for asphalt shingles, and fall protection products. The company's Health Care segment offers medical and surgical supplies, skin health and infection prevention products, inhalation and transdermal drug delivery systems, dental and orthodontic products, health information systems, and food safety products. Its Electronics and Energy segment provides optical films; packaging and interconnection devices; insulating and splicing solutions; touch screens and touch monitors; renewable energy component solutions; and infrastructure protection products. The company's Consumer segment offers sponges, scouring pads, high-performance cloths, repositionable notes, indexing systems, home improvement and care products, protective materials, and consumer and office tapes and adhesives. The company serves automotive, electronics and energy, appliance, paper and printing, packaging, food and beverage, construction, medical clinics and hospitals, pharmaceuticals, dental and orthodontic practitioners, health information systems, food manufacturing and testing, consumer and office retail, office business to business, home improvement, drug and pharmacy retail, and other markets directly, as well as through wholesalers, retailers, jobbers, distributors, and dealers. The company was founded in 1902 and is headquartered in St. Paul, Minnesota.",
#  "mailing_address": "3M CENTER, BLDG. 220-11W-02, ST. PAUL, MN 55144-1000",
#  "name": "3M Co",
#  "sector": "Industrial Goods",
#  "securities": [
#   {
#    "composite_figi": "BBG000BP52R2",
#    "composite_figi_ticker": "MMM:US",
#    "currency": "USD",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XNYS",
#    "figi": "BBG000BP52R2",
#    "figi_exch_cntry": "US",
#    "figi_ticker": "MMM:US",
#    "figi_uniqueid": "EQ0010100100001000",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XNYS",
#    "primary_listing": true,
#    "security_name": "3M CO",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "NYSE",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": null,
#    "composite_figi_ticker": null,
#    "currency": "USD",
#    "delisted_security": true,
#    "etf": false,
#    "exch_symbol": "^XSVA",
#    "figi": null,
#    "figi_exch_cntry": null,
#    "figi_ticker": null,
#    "figi_uniqueid": null,
#    "last_crsp_adj_date": null,
#    "market_sector": null,
#    "mic": "XSVA",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Ordinary Shares",
#    "share_class_figi": null,
#    "stock_exchange": "SVA",
#    "ticker": "AMMM"
#   },
#   {
#    "composite_figi": "BBG000C1VT14",
#    "composite_figi_ticker": "MMM:SW",
#    "currency": "CHF",
#    "delisted_security": true,
#    "etf": false,
#    "exch_symbol": "^XBRN",
#    "figi": "BBG006M6Y8Y6",
#    "figi_exch_cntry": "BW",
#    "figi_ticker": "MMM:BW",
#    "figi_uniqueid": "EQ0010100100022000",
#    "last_crsp_adj_date": null,
#    "market_sector": "Equity",
#    "mic": "XBRN",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "BRN",
#    "ticker": "US88579Y1010"
#   },
#   {
#    "composite_figi": "BBG004BWYX35",
#    "composite_figi_ticker": "MMM:CI",
#    "currency": "USD",
#    "delisted_security": true,
#    "etf": false,
#    "exch_symbol": "^XSGO",
#    "figi": "BBG004BWYX35",
#    "figi_exch_cntry": "CI",
#    "figi_ticker": "MMM:CI",
#    "figi_uniqueid": "EQ0000000029270398",
#    "last_crsp_adj_date": "2014-03-14",
#    "market_sector": "Equity",
#    "mic": "XSGO",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "SGO",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XHAN",
#    "figi": "BBG000C1VQW6",
#    "figi_exch_cntry": "GI",
#    "figi_ticker": "MMM:GI",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2016-11-16",
#    "market_sector": "Equity",
#    "mic": "XHAN",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "HAN",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XHAM",
#    "figi": "BBG000C1VR63",
#    "figi_exch_cntry": "GH",
#    "figi_ticker": "MMM:GH",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XHAM",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "HAM",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XDUS",
#    "figi": "BBG000C1VNC5",
#    "figi_exch_cntry": "GD",
#    "figi_ticker": "MMM:GD",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2017-08-22",
#    "market_sector": "Equity",
#    "mic": "XDUS",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "DUS",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XMUN",
#    "figi": "BBG000C1VPL0",
#    "figi_exch_cntry": "GM",
#    "figi_ticker": "MMM:GM",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2017-08-22",
#    "market_sector": "Equity",
#    "mic": "XMUN",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "MUN",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XSTU",
#    "figi": "BBG000C1VPB1",
#    "figi_exch_cntry": "GS",
#    "figi_ticker": "MMM:GS",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XSTU",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "STU",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": null,
#    "composite_figi_ticker": null,
#    "currency": "SEK",
#    "delisted_security": true,
#    "etf": false,
#    "exch_symbol": "^XSTO",
#    "figi": null,
#    "figi_exch_cntry": null,
#    "figi_ticker": null,
#    "figi_uniqueid": null,
#    "last_crsp_adj_date": null,
#    "market_sector": null,
#    "mic": "XSTO",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Ordinary Shares",
#    "share_class_figi": null,
#    "stock_exchange": "STO",
#    "ticker": "E-US88579Y1010"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XETR",
#    "figi": "BBG000C1VP49",
#    "figi_exch_cntry": "GY",
#    "figi_ticker": "MMM:GY",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XETR",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "XETRA",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XFRA",
#    "figi": "BBG000C1VN17",
#    "figi_exch_cntry": "GF",
#    "figi_ticker": "MMM:GF",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XFRA",
#    "primary_listing": false,
#    "security_name": "3M CO",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "FRA",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VT14",
#    "composite_figi_ticker": "MMM:SW",
#    "currency": "CHF",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XSWX",
#    "figi": "BBG000C1VTJ5",
#    "figi_exch_cntry": "SE",
#    "figi_ticker": "MMM:SE",
#    "figi_uniqueid": "EQ0010100100022000",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XSWX",
#    "primary_listing": false,
#    "security_name": "3M CO",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "SIX",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000HSBCQ2",
#    "composite_figi_ticker": "MMM*:MM",
#    "currency": "MXN",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XMEX",
#    "figi": "BBG000HSBD80",
#    "figi_exch_cntry": "MM",
#    "figi_ticker": "MMM*:MM",
#    "figi_uniqueid": "EQ0000000000608991",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XMEX",
#    "primary_listing": false,
#    "security_name": "3M CO",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "MEX",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG0058MHFJ9",
#    "composite_figi_ticker": "MMMCHF:XL",
#    "currency": "CHF",
#    "delisted_security": true,
#    "etf": false,
#    "exch_symbol": "^XLON",
#    "figi": "BBG0058MHFT8",
#    "figi_exch_cntry": "XL",
#    "figi_ticker": "MMMCHF:XL",
#    "figi_uniqueid": "EQ0000000031670844",
#    "last_crsp_adj_date": "2015-05-20",
#    "market_sector": "Equity",
#    "mic": "XLON",
#    "primary_listing": false,
#    "security_name": "3M CO",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "LSE",
#    "ticker": "0QNY"
#   },
#   {
#    "composite_figi": "BBG00725M611",
#    "composite_figi_ticker": "MMMEUR:XA",
#    "currency": "EUR",
#    "delisted_security": true,
#    "etf": false,
#    "exch_symbol": "^XWBO",
#    "figi": "BBG00725M6K0",
#    "figi_exch_cntry": "XA",
#    "figi_ticker": "MMMEUR:XA",
#    "figi_uniqueid": "EQ0000000037275853",
#    "last_crsp_adj_date": null,
#    "market_sector": "Equity",
#    "mic": "XWBO",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "WBO",
#    "ticker": "MMM"
#   },
#   {
#    "composite_figi": "BBG000C1VMJ0",
#    "composite_figi_ticker": "MMM:GR",
#    "currency": "EUR",
#    "delisted_security": false,
#    "etf": false,
#    "exch_symbol": "^XBER",
#    "figi": "BBG000C1VQB9",
#    "figi_exch_cntry": "GB",
#    "figi_ticker": "MMM:GB",
#    "figi_uniqueid": "EQ0010100100001004",
#    "last_crsp_adj_date": "2017-08-23",
#    "market_sector": "Equity",
#    "mic": "XBER",
#    "primary_listing": false,
#    "security_name": "3M CO.",
#    "security_type": "Common Stock",
#    "share_class_figi": "BBG001S5T7X2",
#    "stock_exchange": "BER",
#    "ticker": "MMM"
#   }
#  ],
#  "short_description": "3M Co. is a diversified technology company, which manufactures industrial, safety and consumer products. The company operates its business through the following segments: Industrial, Safety & Graphics, Health Care, Electronics & Energy, and Consumer. The Industrial segment provides products, including tapes, abrasives, adhesives, specialty materials and filtration systems to diverse markets from purification to aerospace. The Safety & Graphics segment offers personal protective equipment, traffic safety & security products, commercial graphics systems, commercial cleaning & protection products, floor matting, roofing granules for asphalt shingles, and fall protection products. The Health Care segment supplies medical and surgical equipment, skin health & infection prevention products, drug delivery systems, dental & orthodontic products, health information systems and food safety products. The Electronics & Energy segment offers optical films solutions for electronic displays, packaging and interconnection devices; insulating and splicing solutions; touch screens and touch monitors; renewable energy component solutions; and infrastructure protection products. The Consumer segment provides sponges, scouring pads, high-performance cloths, consumer and office tapes, repositionable notes, indexing systems, home improvement products, home care products, protective material products, and consumer & office tapes, as well as adhesives. The company was founded by Henry S. Bryan, Hermon W. Cable, John Dwan, William A. McGonagle and J. Danley Budd in 1902 and is headquartered in St. Paul, MN.",
#  "sic": 3841,
#  "standardized_active": true,
#  "stock_exchange": "NYSE",
#  "template": "industrial",
#  "ticker": "MMM"
# }

# %%
#!jupyter nbconvert --to script md_intrinio_client.ipynb

# %%
import os
def get_SandP_metadata():
    count = 0
    if not os.path.exists("data"):
        os.makedirs("data")
    for entry in sp500:
        datafileName = "./data/data_" + str(entry["symbol"]+".json")
        with open(datafileName, "w") as outfile:
            data = intrinio_get_company_metadata(entry["symbol"])
            json.dump(data, outfile, indent=1, sort_keys=True)
            count += 1


# Reading data back
def test_SandP_metadata():
        with open('data/data_MMM.json', 'r') as f:
                data = json.load(f)

        print(data)
